# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('data/games-features.csv')

# %%
df.head()
# Out:
#    QueryID  ResponseID                  QueryName               ResponseName  \
# 0       10          10             Counter-Strike             Counter-Strike
# 1       20          20      Team Fortress Classic      Team Fortress Classic
# 2       30          30              Day of Defeat              Day of Defeat
# 3       40          40         Deathmatch Classic         Deathmatch Classic
# 4       50          50  Half-Life: Opposing Force  Half-Life: Opposing Force
#
#   ReleaseDate  RequiredAge  DemoCount  DeveloperCount  DLCCount  Metacritic  \
# 0  Nov 1 2000            0          0               1         0          88
# 1  Apr 1 1999            0          0               1         0           0
# 2  May 1 2003            0          0               1         0          79
# 3  Jun 1 2001            0          0               1         0           0
# 4  Nov 1 1999            0          0               1         0           0
#
#    ...  LegalNotice  Reviews  \
# 0  ...
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 13357 entries, 0 to 13356
# Data columns (total 78 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   QueryID                      13357 non-null  int64
#  1   ResponseID                   13357 non-null  int64
#  2   QueryName                    13356 non-null  object
#  3   ResponseName                 13357 non-null  object
#  4   ReleaseDate                  13357 non-null  object
#  5   RequiredAge                  13357 non-null  int64
#  6   DemoCount                    13357 non-null  int64
#  7   DeveloperCount               13357 non-null  int64
#  8   DLCCount                     13357 non-null  int64
#  9   Metacritic                   13357 non-null  int64
#  10  MovieCount                   13357 non-null  int64
#  11  PackageCount                 13357 non-null  int64
#  12  RecommendationCount          13357 non-null  int64
# ...

# %%
df.columns
# Out:
# Index(['QueryID', 'ResponseID', 'QueryName', 'ResponseName', 'ReleaseDate',
#        'RequiredAge', 'DemoCount', 'DeveloperCount', 'DLCCount', 'Metacritic',
#        'MovieCount', 'PackageCount', 'RecommendationCount', 'PublisherCount',
#        'ScreenshotCount', 'SteamSpyOwners', 'SteamSpyOwnersVariance',
#        'SteamSpyPlayersEstimate', 'SteamSpyPlayersVariance',
#        'AchievementCount', 'AchievementHighlightedCount', 'ControllerSupport',
#        'IsFree', 'FreeVerAvail', 'PurchaseAvail', 'SubscriptionAvail',
#        'PlatformWindows', 'PlatformLinux', 'PlatformMac', 'PCReqsHaveMin',
#        'PCReqsHaveRec', 'LinuxReqsHaveMin', 'LinuxReqsHaveRec',
#        'MacReqsHaveMin', 'MacReqsHaveRec', 'CategorySinglePlayer',
#        'CategoryMultiplayer', 'CategoryCoop', 'CategoryMMO',
#        'CategoryInAppPurchase', 'CategoryIncludeSrcSDK',
#        'CategoryIncludeLevelEditor', 'CategoryVRSupport', 'GenreIsNonGame',
# ...

# %%
df_new = df[['QueryName','ReleaseDate', 'RecommendationCount', 'AchievementCount', 'ControllerSupport', 'CategorySinglePlayer', 'CategoryMultiplayer', 'CategoryCoop', 'CategoryMMO', 'CategoryInAppPurchase',
            'CategoryVRSupport', 'GenreIsNonGame','GenreIsIndie', 'GenreIsAction', 'GenreIsAdventure', 'GenreIsCasual','GenreIsStrategy', 'GenreIsRPG', 'GenreIsSimulation','GenreIsEarlyAccess', 'GenreIsFreeToPlay', 'GenreIsSports',
       'GenreIsRacing', 'GenreIsMassivelyMultiplayer', 'PriceFinal', 'ShortDescrip', 'DetailedDescrip', 'Website', 'Reviews']]

# %%
df_new
# Out:
#                        QueryName  ReleaseDate  RecommendationCount  \
# 0                 Counter-Strike   Nov 1 2000                68991
# 1          Team Fortress Classic   Apr 1 1999                 2439
# 2                  Day of Defeat   May 1 2003                 2319
# 3             Deathmatch Classic   Jun 1 2001                  888
# 4      Half-Life: Opposing Force   Nov 1 1999                 2934
# ...                          ...          ...                  ...
# 13352              Baseball Riot  Jan 17 2017                    0
# 13353                  Passage 4  Dec 13 2016                    0
# 13354                 Piximalism  Sep 26 2019                    0
# 13355                 Technoball  Dec 12 2016                    0
# 13356           Ghostlight Manor  Dec 12 2016                    0
#
#        AchievementCount  ControllerSupport  CategorySinglePlayer  \
# 0                     0              False                 False
# ...

# %%
df_new = df_new.apply(lambda x: x.astype(str).str.lower())

# %%
df_new.replace({'true': 1, 'false': 0}, inplace = True)

# %%
df_new.to_csv('data/games-features-cleaned.csv', index = False)

# %%
df_new
# Out:
#                        QueryName  ReleaseDate RecommendationCount  \
# 0                 counter-strike   nov 1 2000               68991
# 1          team fortress classic   apr 1 1999                2439
# 2                  day of defeat   may 1 2003                2319
# 3             deathmatch classic   jun 1 2001                 888
# 4      half-life: opposing force   nov 1 1999                2934
# ...                          ...          ...                 ...
# 13352              baseball riot  jan 17 2017                   0
# 13353                  passage 4  dec 13 2016                   0
# 13354                 piximalism  sep 26 2019                   0
# 13355                 technoball  dec 12 2016                   0
# 13356           ghostlight manor  dec 12 2016                   0
#
#       AchievementCount  ControllerSupport  CategorySinglePlayer  \
# 0                    0                  0                     0
# ...

# %%
ddf = pd.read_csv('data/steam_games.csv')

# %%
ddf.head()
# Out:
#                                                  url types  \
# 0    https://store.steampowered.com/app/379720/DOOM/   app
# 1  https://store.steampowered.com/app/578080/PLAY...   app
# 2  https://store.steampowered.com/app/637090/BATT...   app
# 3    https://store.steampowered.com/app/221100/DayZ/   app
# 4  https://store.steampowered.com/app/8500/EVE_On...   app
#
#                             name  \
# 0                           DOOM
# 1  PLAYERUNKNOWN'S BATTLEGROUNDS
# 2                     BATTLETECH
# 3                           DayZ
# 4                     EVE Online
#
#                                         desc_snippet  \
# 0  Now includes all three premium DLC packs (Unto...
# 1  PLAYERUNKNOWN'S BATTLEGROUNDS is a battle roya...
# 2  Take command of your own mercenary outfit of '...
# 3  The post-soviet country of Chernarus is struck...
# 4  EVE Online is a community-driven spaceship MMO...
#
#                                       recent_reviews  \
# ...

# %%
ddf.shape
# Out:
# (40833, 20)

# %%
ddf_new = ddf.drop(columns = ['types', 'desc_snippet', 'languages', 'achievements', 'game_details', 'game_description', 'mature_content', 'minimum_requirements', 'recommended_requirements', 'discount_price'])

# %%
ddf_new.shape
# Out:
# (40833, 10)

# %%
ddf_new = ddf_new.apply(lambda x: x.astype(str).str.lower())

# %%
ddf_new.head()
# Out:
#                                                  url  \
# 0    https://store.steampowered.com/app/379720/doom/
# 1  https://store.steampowered.com/app/578080/play...
# 2  https://store.steampowered.com/app/637090/batt...
# 3    https://store.steampowered.com/app/221100/dayz/
# 4  https://store.steampowered.com/app/8500/eve_on...
#
#                             name  \
# 0                           doom
# 1  playerunknown's battlegrounds
# 2                     battletech
# 3                           dayz
# 4                     eve online
#
#                                       recent_reviews  \
# 0  very positive,(554),- 89% of the 554 user revi...
# 1  mixed,(6,214),- 49% of the 6,214 user reviews ...
# 2  mixed,(166),- 54% of the 166 user reviews in t...
# 3  mixed,(932),- 57% of the 932 user reviews in t...
# 4  mixed,(287),- 54% of the 287 user reviews in t...
#
#                                          all_reviews  release_date  \
# ...

# %%
ddf_new['recent_reviews'].unique()
# Out:
# array(['very positive,(554),- 89% of the 554 user reviews in the last 30 days are positive.',
#        'mixed,(6,214),- 49% of the 6,214 user reviews in the last 30 days are positive.',
#        'mixed,(166),- 54% of the 166 user reviews in the last 30 days are positive.',
#        ...,
#        'very negative,(20),- 15% of the 20 user reviews in the last 30 days are positive.',
#        'very negative,(13),- 7% of the 13 user reviews in the last 30 days are positive.',
#        'mixed,(40),- 50% of the 40 user reviews in the last 30 days are positive.'],
#       dtype=object)

# %%
ddf_new.loc[ddf_new['recent_reviews'].str.startswith('very positive'), 'recent_reviews'] = 'very positive'

ddf_new.loc[ddf_new['recent_reviews'].str.startswith('mixed'), 'recent_reviews'] = 'mixed'

ddf_new.loc[ddf_new['recent_reviews'].str.startswith('mostly positive'), 'recent_reviews'] = 'mostly positive'

ddf_new.loc[ddf_new['recent_reviews'].str.startswith('overwhelmingly positive'), 'recent_reviews'] = 'overwhelmingly positive'

ddf_new.loc[ddf_new['recent_reviews'].str.startswith('very negative'), 'recent_reviews'] = 'very negative'

ddf_new.loc[ddf_new['recent_reviews'].str.startswith('mostly negative'), 'recent_reviews'] = 'mostly negative'

ddf_new.loc[ddf_new['recent_reviews'].str.startswith('overwhelmingly negative'), 'recent_reviews'] = 'overwhelmingly negative'

# %%
ddf_new['recent_reviews'].unique()
# Out:
# array(['very positive', 'mixed', 'nan', 'mostly positive',
#        'overwhelmingly positive', 'mostly negative',
#        'overwhelmingly negative', 'very negative'], dtype=object)

# %%
ddf_new.loc[ddf_new['all_reviews'].str.startswith('very positive'), 'all_reviews'] = 'very positive'

ddf_new.loc[ddf_new['all_reviews'].str.startswith('mixed'), 'all_reviews'] = 'mixed'

ddf_new.loc[ddf_new['all_reviews'].str.startswith('mostly positive'), 'all_reviews'] = 'mostly positive'

ddf_new.loc[ddf_new['all_reviews'].str.startswith('overwhelmingly positive'), 'all_reviews'] = 'overwhelmingly positive'

ddf_new.loc[ddf_new['all_reviews'].str.startswith('very negative'), 'all_reviews'] = 'very negative'

ddf_new.loc[ddf_new['all_reviews'].str.startswith('mostly negative'), 'all_reviews'] = 'mostly negative'

ddf_new.loc[ddf_new['all_reviews'].str.startswith('overwhelmingly negative'), 'all_reviews'] = 'overwhelmingly negative'

ddf_new.loc[ddf_new['all_reviews'].str.startswith('positive'), 'all_reviews'] = 'positive'

ddf_new.loc[ddf_new['all_reviews'].str.startswith('negative'), 'all_reviews'] = 'negative'

# %%
ddf_new['all_reviews'].unique()
# Out:
# array(['very positive', 'mixed', 'mostly positive', 'nan',
#        'overwhelmingly positive',
#        '7 user reviews,- need more user reviews to generate a score',
#        'positive',
#        '1 user reviews,- need more user reviews to generate a score',
#        'mostly negative',
#        '5 user reviews,- need more user reviews to generate a score',
#        '3 user reviews,- need more user reviews to generate a score',
#        '2 user reviews,- need more user reviews to generate a score',
#        '4 user reviews,- need more user reviews to generate a score',
#        '9 user reviews,- need more user reviews to generate a score',
#        '6 user reviews,- need more user reviews to generate a score',
#        '8 user reviews,- need more user reviews to generate a score',
#        'negative', 'very negative', 'overwhelmingly negative'],
#       dtype=object)

# %%
ddf_new.loc[ddf_new['all_reviews'].str.endswith('need more user reviews to generate a score'),  'all_reviews'] = 'nan'

ddf_new.loc[ddf_new['all_reviews'].str.endswith('need more user reviews to generate a score'),  'all_reviews'] = 'nan'

# %%
ddf_new['all_reviews'].unique()
# Out:
# array(['very positive', 'mixed', 'mostly positive', 'nan',
#        'overwhelmingly positive', 'positive', 'mostly negative',
#        'negative', 'very negative', 'overwhelmingly negative'],
#       dtype=object)

# %%
ddf_new['release_date'] = [x[-4:] for x in ddf_new['release_date']]

# %%
ddf_new
# Out:
#                                                      url  \
# 0        https://store.steampowered.com/app/379720/doom/
# 1      https://store.steampowered.com/app/578080/play...
# 2      https://store.steampowered.com/app/637090/batt...
# 3        https://store.steampowered.com/app/221100/dayz/
# 4      https://store.steampowered.com/app/8500/eve_on...
# ...                                                  ...
# 40828  https://store.steampowered.com/app/899836/rock...
# 40829  https://store.steampowered.com/app/899832/rock...
# 40830  https://store.steampowered.com/app/906840/fant...
# 40831  https://store.steampowered.com/app/906635/mega...
# 40832  https://store.steampowered.com/app/908000/stor...
#
#                                                     name recent_reviews  \
# 0                                                   doom  very positive
# 1                          playerunknown's battlegrounds          mixed
# ...

# %%
ddf_new['release_date'] = ddf_new['release_date'].apply(lambda x: np.where(x.isdigit(), x, '1900'))

# %%
ddf_new['release_date']
# Out:
# 0        2016
# 1        2017
# 2        2018
# 3        2018
# 4        2003
#          ...
# 40828    2019
# 40829    2019
# 40830    2018
# 40831    2018
# 40832    2018
# Name: release_date, Length: 40833, dtype: object

# %%
ddf_new['release_date'].value_counts()
# Out:
# 2018    9819
# 2017    7318
# 2019    5542
# 2016    5333
# 1900    3738
# 2015    3252
# 2014    1930
# 2013     980
# 2012     688
# 2011     432
# 2010     326
# 2009     265
# 2008     163
# 2020     145
# 2007     130
# 2006     119
# 2005      86
# 2003      74
# 2004      62
# 2001      51
# 1999      50
# 2002      42
# 1998      42
# 2000      38
# 1996      37
# 1997      36
# 1995      29
# 1994      25
# 1993      20
# 1990       9
# 1992       8
# 2021       8
# 1991       8
# 1989       6
# 1988       5
# 1987       4
# 2022       4
# 1984       2
# 2023       1
# 2025       1
# 1201       1
# 1981       1
# 1986       1
# 1985       1
# 1983       1
# Name: release_date, dtype: int64

# %%
ddf_new.loc[ddf_new['release_date'].str.endswith('1201'),  'release_date'] = '1900'

# %%
ddf_new.loc[ddf_new['release_date'].str.endswith('0'),  'release_date'] = '1900'

# %%
ddf_new['release_date'].value_counts()
# Out:
# 2018    9819
# 2017    7318
# 2019    5542
# 2016    5333
# 1900    4257
# 2015    3252
# 2014    1930
# 2013     980
# 2012     688
# 2011     432
# 2009     265
# 2008     163
# 2007     130
# 2006     119
# 2005      86
# 2003      74
# 2004      62
# 2001      51
# 1999      50
# 2002      42
# 1998      42
# 1996      37
# 1997      36
# 1995      29
# 1994      25
# 1993      20
# 2021       8
# 1992       8
# 1991       8
# 1989       6
# 1988       5
# 1987       4
# 2022       4
# 1984       2
# 2023       1
# 1985       1
# 1983       1
# 1986       1
# 1981       1
# 2025       1
# Name: release_date, dtype: int64

# %%
ddf_new['all_reviews'].replace({'nan': 0, 'overwhelmingly negative': 1, 'very negative': 2, 'mostly negative': 3, 'negative': 4,
                               'mixed': 5, 'positive': 6, 'mostly positive': 7, 'very positive': 8, 'overwhelmingly positive': 9}, inplace = True)

# %%
ddf_new['all_reviews'].unique()
# Out:
# array([8, 5, 7, 0, 9, 6, 3, 4, 2, 1], dtype=int64)

# %%
ddf_new.head()
# Out:
#                                                  url  \
# 0    https://store.steampowered.com/app/379720/doom/
# 1  https://store.steampowered.com/app/578080/play...
# 2  https://store.steampowered.com/app/637090/batt...
# 3    https://store.steampowered.com/app/221100/dayz/
# 4  https://store.steampowered.com/app/8500/eve_on...
#
#                             name recent_reviews  all_reviews release_date  \
# 0                           doom  very positive            8         2016
# 1  playerunknown's battlegrounds          mixed            5         2017
# 2                     battletech          mixed            7         2018
# 3                           dayz          mixed            5         2018
# 4                     eve online          mixed            7         2003
#
#              developer                                publisher  \
# 0          id software    bethesda softworks,bethesda softworks
# 1     pubg corporation        pubg corporation,pubg corporation
# ...

# %%
ddf_new.isnull().sum()
# Out:
# url               0
# name              0
# recent_reviews    0
# all_reviews       0
# release_date      0
# developer         0
# publisher         0
# popular_tags      0
# genre             0
# original_price    0
# dtype: int64

# %%
ddf_new.to_csv('data/steam_games_cleaned.csv', index = False)
